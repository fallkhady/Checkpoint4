# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as plt
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
file = pd.read_csv('./titanic-passengers.csv')
type(file)
# Out:
# pandas.core.frame.DataFrame

# %%
file.head()
# Out:
#                    PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Ticket;Fare;Cabin;Embarked
# 343;No;2;Collander       Mr. Erik Gustaf;male;28.0;0;0;248740;13.0;;S
# 76;No;3;Moen         Mr. Sigurd Hansen;male;25.0;0;0;348123;7.65;F...
# 641;No;3;Jensen      Mr. Hans Peder;male;20.0;0;0;350050;7.8542000...
# 568;No;3;Palsson     Mrs. Nils (Alma Cornelia Berglund);female;29....
# 672;No;1;Davidson    Mr. Thornton;male;31.0;1;0;F.C. 12750;52.0;B71;S

# %%
file.tail()
# Out:
#                     PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Ticket;Fare;Cabin;Embarked
# 10;Yes;2;Nasser       Mrs. Nicholas (Adele Achem);female;14.0;1;0;2...
# 61;No;3;Sirayanian              Mr. Orsen;male;22.0;0;0;2669;7.2292;;C
# 535;No;3;Cacic           Miss. Marija;female;30.0;0;0;315084;8.6625;;S
# 102;No;3;"Petroff     Mr. Pastcho (""Pentcho"")";male;;0;0;349215;7...
# 428;Yes;2;"Phillips   Miss. Kate Florence (""Mrs Kate Louise Philli...

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')
file.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
file.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print(file['Cabin'].head())
# Out:
# 0      NaN
# 1    F G73
# 2      NaN
# 3      NaN
# 4      B71
# Name: Cabin, dtype: object

# %%
print(file['Cabin'].head().isnull())
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Cabin, dtype: bool

# %%
print(file.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(file['Cabin'].value_counts())
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# D              3
# F33            3
#               ..
# A36            1
# E31            1
# B50            1
# D7             1
# C118           1
# Name: Cabin, Length: 147, dtype: int64

# %%
file['Cabin'].fillna('G6',inplace=True)

# %%
file.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
file['Cabin'].fillna('G20',inplace=True)
file.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
file['Cabin'].fillna('G20',inplace=True)

# %%
file.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
print(file['Cabin'].head())
# Out:
# 0       G6
# 1    F G73
# 2       G6
# 3       G6
# 4      B71
# Name: Cabin, dtype: object

# %%
print(file['Cabin'].value_counts())
# Out:
# G6             691
# B96 B98          4
# C23 C25 C27      4
# D                3
# F33              3
#               ...
# A36              1
# E31              1
# B50              1
# D7               1
# C118             1
# Name: Cabin, Length: 147, dtype: int64

# %%
file['Cabin'].fillna('G20',inplace=True)

# %%
file.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
print(file['Cabin'].value_counts())
file['Cabin'].fillna('G20',inplace=True)
file.tail()
# Out:
# G6             691
# B96 B98          4
# C23 C25 C27      4
# D                3
# F33              3
#               ...
# A36              1
# E31              1
# B50              1
# D7               1
# C118             1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
cleanup_nums ={
    "Sex":{"female":0,"male":1}
}
file.replace(cleanup_nums,inplace=True)
file
# Out:
#      PassengerId Survived  Pclass Titre  \
# 0            343       No       2     0
# 1             76       No       3     0
# 2            641       No       3     0
# 3            568       No       3     0
# 4            672       No       1     0
# ..           ...      ...     ...   ...
# 886           10      Yes       2     0
# 887           61       No       3     0
# 888          535       No       3     1
# 889          102       No       3     0
# 890          428      Yes       2     1
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ...

# %%
sns.barplot(x='Sex', y='Age', data=file,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
cleanup_nums ={
    "Survived":{"No":0,"Yes":1}
}
file.replace(cleanup_nums,inplace=True)
file
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
sns.barplot(x='Survived', y='Fare', data=file,hue='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s,ax = plt.subplots( figsize =(12, 10))

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(file)

# %%
fileresult = file[["Pclass","Survived"]].groupby( ["Pclass"] ,as_index=True).mean()
fileresult
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
file.drop(["Name"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343         0       2    1  28.0      0      0      248740
# 1             76         0       3    1  25.0      0      0      348123
# 2            641         0       3    1  20.0      0      0      350050
# 3            568         0       3    0  29.0      0      4      349909
# 4            672         0       1    1  31.0      1      0  F.C. 12750
# ..           ...       ...     ...  ...   ...    ...    ...         ...
# 886           10         1       2    0  14.0      1      0      237736
# 887           61         0       3    1  22.0      0      0        2669
# 888          535         0       3    0  30.0      0      0      315084
# 889          102         0       3    1   NaN      0      0      349215
# 890          428         1       2    0  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000     G6        S
# 1     7.6500  F G73        S
# ...

# %%
Name = file["Name"]
for row in Name:
    test = row.split()   
    file.insert(3, "Titre", 'test[1]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-c1eda74fcfb4> in <module>
#       2 for row in Name:
#       3     test = row.split()
# ----> 4     file.insert(3, "Titre", 'test[1]')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.drop(["Titre"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
Name = file["Name"]
for row in Name:
    test = row.split()   
file.insert(3, "Titre", 'test[1]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-9b1417f1d266> in <module>
#       2 for row in Name:
#       3     test = row.split()
# ----> 4 file.insert(3, "Titre", 'test[1]')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.tail()
# Out:
#      PassengerId  Survived  Pclass    Titre  \
# 886           10         1       2  test[1]
# 887           61         0       3  test[1]
# 888          535         0       3  test[1]
# 889          102         0       3  test[1]
# 890          428         1       2  test[1]
#
#                                                   Name  Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1
# 887                              Sirayanian, Mr. Orsen    1  22.0      0
# 888                                Cacic, Miss. Marija    0  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# ...

# %%
file.drop(["Titre"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
Name = file["Name"]
for row in Name:
      file.insert(3, "Titre", 'row.split(1) ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-bfb9f90211ed> in <module>
#       1 Name = file["Name"]
#       2 for row in Name:
# ----> 3       file.insert(3, "Titre", 'row.split(1) ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.tail()
# Out:
#      PassengerId  Survived  Pclass    Titre  \
# 886           10         1       2  test[1]
# 887           61         0       3  test[1]
# 888          535         0       3  test[1]
# 889          102         0       3  test[1]
# 890          428         1       2  test[1]
#
#                                                   Name  Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1
# 887                              Sirayanian, Mr. Orsen    1  22.0      0
# 888                                Cacic, Miss. Marija    0  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# ...

# %%
file.drop(["Titre"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
file.tail()
# Out:
#      PassengerId  Survived  Pclass    Titre  \
# 886           10         1       2  test[1]
# 887           61         0       3  test[1]
# 888          535         0       3  test[1]
# 889          102         0       3  test[1]
# 890          428         1       2  test[1]
#
#                                                   Name  Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1
# 887                              Sirayanian, Mr. Orsen    1  22.0      0
# 888                                Cacic, Miss. Marija    0  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# ...

# %%
file.drop(["Titre"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
Name = file["Name"]
for row in Name:
      file.insert(3, "Titre", 'row.split(1) ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-bfb9f90211ed> in <module>
#       1 Name = file["Name"]
#       2 for row in Name:
# ----> 3       file.insert(3, "Titre", 'row.split(1) ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.head()
# Out:
#    PassengerId  Survived  Pclass    Titre  \
# 0          343         0       2  test[1]
# 1           76         0       3  test[1]
# 2          641         0       3  test[1]
# 3          568         0       3  test[1]
# 4          672         0       1  test[1]
#
#                                           Name  Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    1  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    1  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    1  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0      4
# 4                       Davidson, Mr. Thornton    1  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000     G6        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542     G6        S
# 3      349909  21.0750     G6        S
# 4  F.C. 12750  52.0000    B71        S

# %%
file.drop(["Titre"],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
for row in Name:
    test = row.split()
    file.insert(3, "Titre", test[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-64a7abeb8dcb> in <module>
#       1 for row in Name:
#       2     test = row.split()
# ----> 3     file.insert(3, "Titre", test[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')

# %%
for row in Name:
    test = row.split()
    file.insert(3, "Titre", test[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-3d73a9fc4766> in <module>
#       1 for row in Name:
#       2     test = row.split()
# ----> 3     file.insert(3, "Titre", test[2])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')

# %%
file.drop(["Name"],axis=1)
# Out:
#      PassengerId Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    male  28.0      0      0      248740
# 1             76       No       3    male  25.0      0      0      348123
# 2            641       No       3    male  20.0      0      0      350050
# 3            568       No       3  female  29.0      0      4      349909
# 4            672       No       1    male  31.0      1      0  F.C. 12750
# ..           ...      ...     ...     ...   ...    ...    ...         ...
# 886           10      Yes       2  female  14.0      1      0      237736
# 887           61       No       3    male  22.0      0      0        2669
# 888          535       No       3  female  30.0      0      0      315084
# 889          102       No       3    male   NaN      0      0      349215
# 890          428      Yes       2  female  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000    NaN        S
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-64a7abeb8dcb> in <module>
#       1 for row in Name:
#       2     test = row.split()
# ----> 3     file.insert(3, "Titre", test[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.tail()
# Out:
#      PassengerId Survived  Pclass Titre  \
# 886           10      Yes       2   Mr.
# 887           61       No       3   Mr.
# 888          535       No       3   Mr.
# 889          102       No       3   Mr.
# 890          428      Yes       2   Mr.
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708   NaN        C
# 887      0    2669   7.2292   NaN        C
# 888      0  315084   8.6625   NaN        S
# 889      0  349215   7.8958   NaN        S
# 890      0  250655  26.0000   NaN        S

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass Titre  \
# 0          343       No       2   Mr.
# 1           76       No       3   Mr.
# 2          641       No       3   Mr.
# 3          568       No       3   Mr.
# 4          672       No       1   Mr.
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    male  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                       Davidson, Mr. Thornton    male  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
file
# Out:
#      PassengerId Survived  Pclass Titre  \
# 0            343       No       2   Mr.
# 1             76       No       3   Mr.
# 2            641       No       3   Mr.
# 3            568       No       3   Mr.
# 4            672       No       1   Mr.
# ..           ...      ...     ...   ...
# 886           10      Yes       2   Mr.
# 887           61       No       3   Mr.
# 888          535       No       3   Mr.
# 889          102       No       3   Mr.
# 890          428      Yes       2   Mr.
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ...

# %%
file.drop(["Titre"],axis=1)
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
for row in Name:
    test = row.split()
    file.insert(3, "Titre", test[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-7da9385bd36f> in <module>
#       1 for row in Name:
#       2     test = row.split()
# ----> 3     file.insert(3, "Titre", test[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass       Titre  \
# 0          343       No       2  Collander,
# 1           76       No       3  Collander,
# 2          641       No       3  Collander,
# 3          568       No       3  Collander,
# 4          672       No       1  Collander,
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    male  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                       Davidson, Mr. Thornton    male  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
for row in Name:
    test = row.split()
    file.insert(3, "Titre", test[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-7da9385bd36f> in <module>
#       1 for row in Name:
#       2     test = row.split()
# ----> 3     file.insert(3, "Titre", test[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass       Titre  \
# 0          343       No       2  Collander,
# 1           76       No       3  Collander,
# 2          641       No       3  Collander,
# 3          568       No       3  Collander,
# 4          672       No       1  Collander,
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    male  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                       Davidson, Mr. Thornton    male  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
for row in Name:
    test = row.split()
file.insert(3, "Titre", test[0])

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass      Titre  \
# 0          343       No       2  Phillips,
# 1           76       No       3  Phillips,
# 2          641       No       3  Phillips,
# 3          568       No       3  Phillips,
# 4          672       No       1  Phillips,
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    male  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                       Davidson, Mr. Thornton    male  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')

# %%
Name = file["Name"]
for row in Name:
    test = row.split()
    file.insert(3, "Titre", test[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-9d6daa2e1ef6> in <module>
#       2 for row in Name:
#       3     test = row.split()
# ----> 4     file.insert(3, "Titre", test[1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# ...

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
file = pd.read_csv('./titanic-passengers.csv', sep=';')

# %%
L = []
Name = file["Name"]
for row in Name:
    test = row.split()
    L.append(test[1])
file.insert(3, "Titre", L)

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass Titre  \
# 0          343       No       2   Mr.
# 1           76       No       3   Mr.
# 2          641       No       3   Mr.
# 3          568       No       3  Mrs.
# 4          672       No       1   Mr.
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    male  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                       Davidson, Mr. Thornton    male  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
file.tail()
# Out:
#      PassengerId Survived  Pclass  Titre  \
# 886           10      Yes       2   Mrs.
# 887           61       No       3    Mr.
# 888          535       No       3  Miss.
# 889          102       No       3    Mr.
# 890          428      Yes       2  Miss.
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708   NaN        C
# 887      0    2669   7.2292   NaN        C
# 888      0  315084   8.6625   NaN        S
# 889      0  349215   7.8958   NaN        S
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
Title_Dictionary = {

                     "Capt.":       "Officer",

                    "Col.":        "Officer",

                    "Major.":      "Officer",

                      "Dr.":         "Officer",

                    "Rev.":        "Officer",

                    "Jonkheer.":   "Royalty",

                    "Don.":        "Royalty",

                    "Sir." :       "Royalty",

                   "Lady." :      "Royalty",

                  "the Countess.": "Royalty",

                    "Dona.":       "Royalty",

                    "Mme.":        "Miss",

                    "Mlle.":       "Miss",

                    "Miss." :      "Miss",

                    "Ms.":         "Mrs",

                    "Mr." :        "Mrs",

                    "Mrs." :       "Mrs",

                    "Master." :    "Master"

                    }

file.replace(Title_Dictionary,inplace=True)
file
# Out:
#      PassengerId Survived  Pclass Titre  \
# 0            343       No       2   Mrs
# 1             76       No       3   Mrs
# 2            641       No       3   Mrs
# 3            568       No       3   Mrs
# 4            672       No       1   Mrs
# ..           ...      ...     ...   ...
# 886           10      Yes       2   Mrs
# 887           61       No       3   Mrs
# 888          535       No       3  Miss
# 889          102       No       3   Mrs
# 890          428      Yes       2  Miss
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ...

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass Titre  \
# 0          343       No       2   Mrs
# 1           76       No       3   Mrs
# 2          641       No       3   Mrs
# 3          568       No       3   Mrs
# 4          672       No       1   Mrs
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    male  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                       Davidson, Mr. Thornton    male  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
cleanup_nums ={
    "Titre":{"Mrs":0,"Miss":1,"Master":2,"Royalty":3,"Officer":4}
}
file.replace(cleanup_nums,inplace=True)
file
# Out:
#      PassengerId Survived  Pclass Titre  \
# 0            343       No       2     0
# 1             76       No       3     0
# 2            641       No       3     0
# 3            568       No       3     0
# 4            672       No       1     0
# ..           ...      ...     ...   ...
# 886           10      Yes       2     0
# 887           61       No       3     0
# 888          535       No       3     1
# 889          102       No       3     0
# 890          428      Yes       2     1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ...

# %%
sns.barplot(x='Titre', y='Age', data=file,hue='Titre')
# Out:
# <AxesSubplot:xlabel='Titre', ylabel='Age'>

# %%
sns.barplot(x='Titre', y='Fare', data=file,hue='Titre')
# Out:
# <AxesSubplot:xlabel='Titre', ylabel='Fare'>

# %%
file.head()
# Out:
#    PassengerId Survived  Pclass Titre  \
# 0          343       No       2     0
# 1           76       No       3     0
# 2          641       No       3     0
# 3          568       No       3     0
# 4          672       No       1     0
#
#                                           Name  Sex   Age  SibSp  Parch  \
# 0                   Collander, Mr. Erik Gustaf    1  28.0      0      0
# 1                      Moen, Mr. Sigurd Hansen    1  25.0      0      0
# 2                       Jensen, Mr. Hans Peder    1  20.0      0      0
# 3  Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.0      0      4
# 4                       Davidson, Mr. Thornton    1  31.0      1      0
#
#        Ticket     Fare  Cabin Embarked
# 0      248740  13.0000    NaN        S
# 1      348123   7.6500  F G73        S
# 2      350050   7.8542    NaN        S
# 3      349909  21.0750    NaN        S
# 4  F.C. 12750  52.0000    B71        S

# %%
sns.barplot(x='Titre', y='Fare', data=file,hue='Titre')
# Out:
# <AxesSubplot:xlabel='Titre', ylabel='Fare'>
